# %% [markdown]
# # Zbx Clean Other
#
# This notebook was created to perform semi-automatic cleaning of Zabbix database by interacting with files for mass data review and update.
#
# This was designed to work with the hosts associated with the equipments from CELPLAM, ROHDE&SCHWARZ
#
# For zabbix interface uses: https://github.com/lukecyca/pyzabbix
#
# Zabbix API documentation at: https://www.zabbix.com/documentation/current/en/manual/api/reference

# %% [markdown]
# ---
#
# <code style="background:red;color:white"><b>ATTENTION:</b> DRAFT VERSION - PLACEHOLDER TO BE DEVELOPED.</code>
#
# ---

# %% [markdown]
# ### Environment setup

# %%
URL_ZABBIX = "http://zabbixsfi.anatel.gov.br/"
TOKEN_ZABBIX = "<PASTE SUPER ADMIN TOKEN HERE>"

HOST_DATA = ["hostids", "host", "name", "status"]
INTER_DATA = ["interfaceid","hostid","type","ip","dns","main"]
GROUP_DATA = ["groupid","name"]
TEMPLATE_DATA = ["templateids","host","name"]

HOST_INTER_CSV = "zbxHostInterface.csv"
HOST_GROUP_CSV = "zbxHostGroup.csv"

CLEAN_DATA = "ZabbixClean.xlsx"
LINK_SHEET = "OutEnlace"
RFEYE_SHEET = "OutRFEye"
RMU_SHEET = "OutRMU"
OTHER_SHEET = "OutOutros"

# %% [markdown]
# ### Includes

# %%
from pyzabbix import ZabbixAPI

import pandas as pd
import numpy as np

# %% [markdown]
# ### Create session

# %%
zapi = ZabbixAPI(URL_ZABBIX)

zapi.session.verify = False # Disable SSL certificate verification

zapi.timeout = 5.1 #seconds

zapi.login(api_token=TOKEN_ZABBIX)

# %% [markdown]
# ### Load host data

# %%
zbx_dict = zapi.host.get(output=HOST_DATA)

df_host = pd.DataFrame(zbx_dict)

# %% [markdown]
# ### Load interface data

# %%
zbx_dict = zapi.hostinterface.get(output=INTER_DATA)

df_inter = pd.DataFrame(zbx_dict)

# %% [markdown]
# ### Combine all data into a single table
#
# Note that hosts with multiple interfaces will show up in multiple rows

# %%
df_full = pd.merge(df_host, df_inter, how='inner', left_on = 'hostid', right_on = 'hostid')

# %% [markdown]
# ### Export host and interface data for external processing using CSV format
#
# At this point one should export data from zabbix and manipulate to create a clean XLSX spreadsheet that shall be used for the new configuration

# %%
df_full.to_csv(HOST_INTER_CSV)

# %% [markdown]
# ### Load template data

# %%
zbx_dict = zapi.template.get(output=TEMPLATE_DATA)

df_template = pd.DataFrame(zbx_dict)

# %%
df_template
# Out:
#                                   host                               name
# 0    Template OS Linux by Zabbix agent  Template OS Linux by Zabbix agent  \
# 1           Template App Zabbix Server         Template App Zabbix Server
# 2            Template App Zabbix Proxy          Template App Zabbix Proxy
# 3         Template Module Zabbix agent       Template Module Zabbix agent
# 4                  Template OS OpenBSD                Template OS OpenBSD
# ..                                 ...                                ...
# 130                   Template Net MTR                   Template Net MTR
# 131                   ERMx FL SmartWeb                   ERMx FL SmartWeb
# 132                      Volt SmartWeb                      Volt SmartWeb
# 133                             CW RMU                             CW RMU
# 134              RFEye OS Linux SNMPv2              RFEye OS Linux SNMPv2
#
#     templateid
# 0        10001
# 1        10047
# 2        10048
# 3        10050
# 4        10074
# ..         ...
# 130      10703
# 131      10744
# 132      10747
# 133      10764
# 134      10791
#
# [135 rows x 3 columns]

# %% [markdown]
# ### Import clean data for RFEye Stations

# %%
df_clean_data = pd.read_excel(CLEAN_DATA, sheet_name=RFEYE_SHEET)

# %%
df_clean_data
# Out:
#      hostid              host              name  status  interfaceid  type
# 0     10613  RFEye002073_OVPN  RFEye002073_OVPN       1          383     2  \
# 1     10365  RFEye002076_OVPN  RFEye002076_OVPN       1           58     2
# 2     10366  RFEye002079_OVPN  RFEye002079_OVPN       1           59     2
# 3     10614  RFEye002081_OVPN  RFEye002081_OVPN       1          384     2
# 4     10496  RFEye002083_OVPN  RFEye002083_OVPN       1          189     2
# ..      ...               ...               ...     ...          ...   ...
# 295   10542  RFEye002328_OVPN  RFEye002328_OVPN       1          235     2
# 296   10543  RFEye002330_OVPN  RFEye002330_OVPN       1          236     2
# 297   10673       RFEye002332       RFEye002332       0          443     2
# 298   10545       RFEye002345       RFEye002345       0          238     2
# 299   10675       RFEye002349       RFEye002349       0          445     2
#
#                ip                         dns  N_host_Oficial  N_host_status
# 0    <ip address>  rfeye002073.rfeyenodes.com           False              1  \
# 1    <ip address>  rfeye002076.rfeyenodes.com           False              1
# 2    <ip address>  rfeye002079.rfeyenodes.com           False              1
# 3    <ip address>  rfeye002081.rfeyenodes.com           False              1
# 4    <ip address>  rfeye002083.rfeyenodes.com           False              1
# ..            ...                         ...             ...            ...
# 295  <ip address>  rfeye002328.rfeyenodes.com            True              1
# 296  <ip address>  rfeye002330.rfeyenodes.com            True              1
# 297  <ip address>  rfeye002332.rfeyenodes.com            True              0
# 298  <ip address>                         NaN            True              0
# 299  <ip address>                         NaN            True              0
#
#      ... N_host_grp_Detentor N_host_grp_Situação N_host_grp_Tipo
# 0    ...                 NaN                 NaN             NaN  \
# 1    ...                 NaN                 NaN             NaN
# 2    ...                 NaN                 NaN             NaN
# 3    ...                 NaN                 NaN             NaN
# 4    ...                 NaN                 NaN             NaN
# ..   ...                 ...                 ...             ...
# 295  ...                GR08               Ativo         Estação
# 296  ...                GR01             Litígio         Estação
# 297  ...                GR01               Ativo         Estação
# 298  ...                GR05               Ativo         Estação
# 299  ...                GR01               Ativo         Estação
#
#     N_host_grp_Modelo N_host_grp_teste N_host_grp_OVPN            IP
# 0                 NaN              NaN            OVPN           NaN  \
# 1                 NaN              NaN            OVPN           NaN
# 2                 NaN              NaN            OVPN           NaN
# 3                 NaN              NaN            OVPN  <IP Address>
# 4                 NaN              NaN            OVPN  <IP Address>
# ..                ...              ...             ...           ...
# 295             RFeye              NaN             NaN  <IP Address>
# 296             RFeye              NaN             NaN           NaN
# 297             RFeye              NaN             NaN  <IP Address>
# 298             RFeye              NaN             NaN  <IP Address>
# 299             RFeye              NaN             NaN  <IP Address>
#
#                            DNS Série  Índice
# 0    rfeye002073.anatel.gov.br  2073      55
# 1    rfeye002076.anatel.gov.br  2076      56
# 2    rfeye002079.anatel.gov.br  2079      57
# 3    rfeye002081.anatel.gov.br  2081      59
# 4    rfeye002083.anatel.gov.br  2083      60
# ..                         ...   ...     ...
# 295  rfeye002328.anatel.gov.br  2328     239
# 296  rfeye002330.anatel.gov.br  2330     240
# 297  rfeye002332.anatel.gov.br  2332     241
# 298  rfeye002345.anatel.gov.br  2345     242
# 299  rfeye002349.anatel.gov.br  2349     243
#
# [300 rows x 35 columns]

# %% [markdown]
# # Update Group

# %% [markdown]
# ### List all groups

# %%
df_clean_data.columns
# Out:
# Index(['hostid', 'host', 'name', 'status', 'interfaceid', 'type', 'ip', 'dns',
#        'Tem OVPN?', 'Tem Teste?', 'N_host_status', 'N_host_name',
#        'N_host_tag_Local', 'N_host_tag_Município', 'N_host_inv_lat',
#        'N_host_inv_lon', 'N_host_inv_city', 'N_host_inv_state',
#        'N_host_inv_poc_1_notes', 'N_host_inv_alias', 'N_host_inv_Asset tag',
#        'N_host_inv_Tag', 'N_host_inv_Type', 'N_host_inv_Model',
#        'N_host_inv_Vendor', 'N_host_grp_UF', 'N_host_grp_Detentor',
#        'N_host_grp_Situação', 'N_host_grp_Tipo', 'N_host_grp_Modelo',
#        'N_host_grp_teste', 'N_host_grp_OVPN', 'IP', 'DNS', 'Série', 'Índice'],
#       dtype='object')

# %%
zbx_dict = zapi.hostgroup.get(output=GROUP_DATA)

df_group = pd.DataFrame(zbx_dict)

# %%
df_group
# Out:
#     groupid                              name
# 0        22                                AC
# 1        23                                AL
# 2        21                                AM
# 3        24                                AP
# 4        50                  Anatel Templates
# ..      ...                               ...
# 116     110                             UO113
# 117      69  Unidade Administrativa da Anatel
# 118       6                  Virtual machines
# 119       4                    Zabbix servers
# 120      78                              xDSL
#
# [121 rows x 2 columns]

# %% [markdown]
# ### Create a dictionary with the groups to be processed

# %%
all_groups = {  'N_host_grp_UF':[],
                'N_host_grp_Detentor':[],
                'N_host_grp_Situação':[],
                'N_host_grp_Tipo':[],
                'N_host_grp_Modelo':[],
                'N_host_grp_teste':[],
                'N_host_grp_OVPN':[]}

for group in all_groups:
    np_array = df_clean_data[group].unique()

    np_array = np_array[~pd.isna(np_array)] # remove NaN 

    all_groups[group] = np_array.tolist()

# %% [markdown]
# ### Create groups in Zabbix if necessary and associate all data within the dataframe with clean data

# %%
for group_list in all_groups:
    
    zbx_group = {'groupid':[0]*all_groups[group_list].__len__(),
                 'name':[""]*all_groups[group_list].__len__()}
    i = 0
    
    for group in all_groups[group_list]:
        
        where_is_group = df_group[df_group.isin([group])].stack().index #get the index from where the group is in the df from zabbix
        
        if len(where_is_group) == 0: #check if the group don't exist in zabbix
            
            zbx_dict = zapi.hostgroup.create(name=group)

            zbx_group['groupid'][i] = zbx_dict['groupids']
            zbx_group['name'][i] = group[0]
        else:
            index = where_is_group.to_numpy()[0][0]
            
            zbx_group['groupid'][i] = df_group['groupid'][index]
            zbx_group['name'][i] = df_group['name'][index]
            
        i = i + 1
        
    df_zbx_group = pd.DataFrame(zbx_group)
    
    df_clean_data = pd.merge(df_clean_data, df_zbx_group, how='left', left_on = group_list, right_on = 'name')
    
    df_clean_data = df_clean_data.rename(columns={"groupid": f"GID {group_list}", "name": f"zbx {group_list}"})

# %% [markdown]
# ### Get hosts assigned to groups (BACKUP)

# %%
def get_group_host(zapi, df_clean_data):

    GROUP_DATA = ["groupid", "name"]
    
    df_output = pd.DataFrame(columns=['groupid', 'name', 'hostid'])

    for hostid in df_clean_data["hostid"].to_list():
        zbx_dict = zapi.hostgroup.get(output=GROUP_DATA, hostids=hostid)
        
        df = pd.DataFrame(zbx_dict)
        df['hostid']=hostid
        
        df_output = pd.concat([df_output,df],ignore_index=True)
        
    return df_output

# df_host_group = get_group_host(zapi, df_clean_data)
# df_host_group
# df_host_group.to_csv(HOST_GROUP_CSV)

# %% [markdown]
# ### Create a list of dictionaries with groups to be removed

# %%
group_dic_list=[]

df = df_group.sort_values(by=["groupid"])
group_list = df['groupid'].to_list()[1:] # get group list except the first

for group in group_list:
    group_dic_list.append({'groupid':group})

# %% [markdown]
# ### Create a list of dictionaries with host to be edited

# %%
host_dic_list=[]

host_list = df_clean_data["hostid"].to_list()

for host in host_list:
    host_dic_list.append({'hostid':host})

# %% [markdown]
# ### Select a reference default group

# %%
default_group = df['groupid'].to_list()[0]

group_List_dict = [{'groupid':default_group}]

# %% [markdown]
# ### Add group 1 to all hosts to be edited

# %%
for host in host_list:
    zbx_dict = zapi.hostgroup.massadd(groups=group_List_dict, hosts=[{'hostid':host}])

# %% [markdown]
# ### Remove all groups from hosts:[],
# except default_group

# %%
for host in host_list:
    zbx_dict = zapi.hostgroup.massremove(groupids=group_list, hostids=host)

# %% [markdown]
# #### Add new groups from clean list

# %%
def add_group(host):
    group_list = [{'groupid':host['GID N_host_grp_UF']},
                  {'groupid':host['GID N_host_grp_Detentor']},
                  {'groupid':host['GID N_host_grp_Situação']},
                  {'groupid':host['GID N_host_grp_Tipo']},
                  {'groupid':host['GID N_host_grp_Modelo']},
                  {'groupid':host['GID N_host_grp_teste']},
                  {'groupid':host['GID N_host_grp_OVPN']}]
    
    group_list = [item for item in group_list if isinstance(item['groupid'], str)]
                
    zbx_dict = zapi.hostgroup.massadd(groups=group_list, hosts=[{'hostid':host['hostid']}])
    
none = df_clean_data.apply(add_group, axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 300    None
# 301    None
# 302    None
# 303    None
# 304    None
# Length: 305, dtype: object

# %% [markdown]
# ### Remove default group

# %%
for host in host_list:
    zbx_dict = zapi.hostgroup.massremove(groupids=[default_group], hostids=[host])

# %% [markdown]
# # Update Inventory

# %% [markdown]
# ### Remove all inventory data

# %%
CLEAN_INVENTORY = { 'alias' : '',
                    'asset_tag' : '',
                    'chassis' : '',
                    'contact' : '',
                    'contract_number' : '',
                    'date_hw_decomm' : '',
                    'date_hw_expiry' : '',
                    'date_hw_install' : '',
                    'date_hw_purchase' : '',
                    'deployment_status' : '',
                    'hardware' : '',
                    'hardware_full' : '',
                    'host_netmask' : '',
                    'host_networks' : '',
                    'host_router' : '',
                    'hw_arch' : '',
                    'installer_name' : '',
                    'location' : '',
                    'location_lat' : '',
                    'location_lon' : '',
                    'macaddress_a' : '',
                    'macaddress_b' : '',
                    'model' : '',
                    'name' : '',
                    'notes' : '',
                    'oob_ip' : '',
                    'oob_netmask' : '',
                    'oob_router' : '',
                    'os' : '',
                    'os_full' : '',
                    'os_short' : '',
                    'poc_1_cell' : '',
                    'poc_1_email' : '',
                    'poc_1_name' : '',
                    'poc_1_notes' : '',
                    'poc_1_phone_a' : '',
                    'poc_1_phone_b' : '',
                    'poc_1_screen' : '',
                    'poc_2_cell' : '',
                    'poc_2_email' : '',
                    'poc_2_name' : '',
                    'poc_2_notes' : '',
                    'poc_2_phone_a' : '',
                    'poc_2_phone_b' : '',
                    'poc_2_screen' : '',
                    'serialno_a' : '',
                    'serialno_b' : '',
                    'site_address_a' : '',
                    'site_address_b' : '',
                    'site_address_c' : '',
                    'site_city' : '',
                    'site_country' : '',
                    'site_notes' : '',
                    'site_rack' : '',
                    'site_state' : '',
                    'site_zip' : '',
                    'software' : '',
                    'software_app_a' : '',
                    'software_app_b' : '',
                    'software_app_c' : '',
                    'software_app_d' : '',
                    'software_app_e' : '',
                    'software_full' : '',
                    'tag' : '',
                    'type' : '',
                    'type_full' : '',
                    'url_a' : '',
                    'url_b' : '',
                    'url_c' : '',
                    'vendor' : ''}

def set_inventory(host):    
    zbx_dict = zapi.host.update(hostid=host['hostid'], inventory_mode='0', inventory=CLEAN_INVENTORY)
    
none = df_clean_data.apply(set_inventory, axis=1)

# %% [markdown]
# ### Add inventory data

# %%
df_clean_data.columns
# Out:
# Index(['hostid', 'host', 'name_x', 'status', 'interfaceid', 'type', 'ip',
#        'dns', 'Tem OVPN?', 'Tem Teste?', 'N_host_status', 'N_host_name',
#        'N_host_tag_Local', 'N_host_tag_Município', 'N_host_inv_lat',
#        'N_host_inv_lon', 'N_host_inv_city', 'N_host_inv_state',
#        'N_host_inv_poc_1_notes', 'N_host_inv_alias', 'N_host_inv_Asset tag',
#        'N_host_inv_Tag', 'N_host_inv_Type', 'N_host_inv_Model',
#        'N_host_inv_Vendor', 'N_host_grp_UF', 'N_host_grp_Detentor',
#        'N_host_grp_Situação', 'N_host_grp_Tipo', 'N_host_grp_Modelo',
#        'N_host_grp_teste', 'N_host_grp_OVPN', 'IP', 'DNS', 'Série', 'Índice',
#        'GID N_host_grp_UF', 'name_y', 'GID N_host_grp_Detentor',
#        'zbx N_host_grp_Detentor', 'GID N_host_grp_Situação',
#        'zbx N_host_grp_Situação', 'GID N_host_grp_Tipo', 'zbx N_host_grp_Tipo',
#        'GID N_host_grp_Modelo', 'zbx N_host_grp_Modelo',
#        'GID N_host_grp_teste', 'zbx N_host_grp_teste', 'GID N_host_grp_OVPN',
#        'zbx N_host_grp_OVPN'],
#       dtype='object')

# %%
host = df_clean_data.iloc[220]

inventory = {'location_lat' : f"{host['N_host_inv_lat']}",
                 'location_lon' : f"{host['N_host_inv_lon']}",
                 'site_city' :    host['N_host_inv_city'],
                 'site_state' :   host['N_host_inv_state'],
                 'poc_1_notes' :  host['N_host_inv_poc_1_notes'],
                 'alias':         host['N_host_inv_alias'],
                 'asset_tag':     host['N_host_inv_Asset tag'],
                 'tag':           host['N_host_inv_Tag'],
                 'type':          host['N_host_inv_Type'],
                 'model':         host['N_host_inv_Model'],
                 'vendor':        host['N_host_inv_Vendor']}

# %%
inventory
# Out:
# {'location_lat': 'nan',
#  'location_lon': 'nan',
#  'site_city': 'Rio Largo',
#  'site_state': 'AL',
#  'poc_1_notes': 'GR06, UO061',
#  'alias': 'Aeroporto Internacional de Maceió',
#  'asset_tag': 62748.0,
#  'tag': 'https://sistemas.anatel.gov.br/fiscaliza/issues/56821',
#  'type': 'Estação TDOA',
#  'model': 'Rfeye Node 20-6',
#  'vendor': 'CRFS'}

# %%
inventory = [item for item in inventory if isinstance(item['groupid'], str) or isinstance(item['groupid'], str)]

# %%
def set_inventory(host):
    inventory = {'location_lat' : f"{host['N_host_inv_lat']}",
                 'location_lon' : f"{host['N_host_inv_lon']}",
                 'site_city' :    host['N_host_inv_city'],
                 'site_state' :   host['N_host_inv_state'],
                 'poc_1_notes' :  host['N_host_inv_poc_1_notes'],
                 'alias':         host['N_host_inv_alias'],
                 'asset_tag':     host['N_host_inv_Asset tag'],
                 'tag':           host['N_host_inv_Tag'],
                 'type':          host['N_host_inv_Type'],
                 'model':         host['N_host_inv_Model'],
                 'vendor':        host['N_host_inv_Vendor']}
    
    inventory = {key: value for key, value in inventory.items() if isinstance(value, str)}
    
    zbx_dict = zapi.host.update(hostid=host['hostid'], inventory_mode='0', inventory=inventory)
    
none = df_clean_data.apply(set_inventory, axis=1)

# %% [markdown]
# # Update Tag data

# %% [markdown]
# ### Clean Tags

# %%
def clean_tag(host):
    zbx_dict = zapi.host.update(hostid=host['hostid'], tags={})
    
none = df_clean_data.apply(clean_tag, axis=1)

# %% [markdown]
# ### Add tag data

# %%
def set_tag(host):
    tag = [{'tag' : 'Local', 'value' : host['N_host_tag_Local']},
           {'tag' : 'Município', 'value' : host['N_host_tag_Município']}]
    
    tag = [item for item in tag if isinstance(item['value'], str)]
    
    zbx_dict = zapi.host.update(hostid=host['hostid'], tags=tag)
    
none = df_clean_data.apply(set_tag, axis=1)

# %% [markdown]
# # Update Template

# %% [markdown]
# Lista hosts e template id - Not realy working... better to use the interface since there are some bug in the use of the API

# %%
zapi.host.get(hostid=["10396"], selectParentTemplates=["templateid","name"])
# Out:
# [{'hostid': '10084',
#   'proxy_hostid': '0',
#   'host': 'rhzbefipdin01',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'Zabbix server',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '1',
#   'parentTemplates': [{'templateid': '10001',
#     'name': 'Template OS Linux by Zabbix agent'},
#    {'templateid': '10047', 'name': 'Template App Zabbix Server'}]},
#  {'hostid': '10305',
#   'proxy_hostid': '0',
#   'host': 'BSA 0766753',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'BSA 0766753',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10324', 'name': 'Oi SNMP'}]},
#  {'hostid': '10307',
#   'proxy_hostid': '0',
#   'host': 'BHE 6767637 old',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'BHE 6767637',
#   'flags': '0',
#   'templateid': '0',
#   'description': '187.76.239.217',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10324', 'name': 'Oi SNMP'}]},
#  {'hostid': '10310',
#   'proxy_hostid': '0',
#   'host': 'BHE 6767635',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'BHE 6767635',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10324', 'name': 'Oi SNMP'}]},
#  {'hostid': '10312',
#   'proxy_hostid': '0',
#   'host': 'BHE 6767639',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'BHE 6767639',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10324', 'name': 'Oi SNMP'}]},
#  {'hostid': '10313',
#   'proxy_hostid': '0',
#   'host': 'BHE 6767629',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'BHE 6767629',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10324', 'name': 'Oi SNMP'}]},
#  {'hostid': '10314',
#   'proxy_hostid': '0',
#   'host': 'CAS_IP_30083',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CAS/IP/30083',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10315',
#   'proxy_hostid': '0',
#   'host': 'GNA 0758312',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'GNA 0758312',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10324', 'name': 'Oi SNMP'}]},
#  {'hostid': '10317',
#   'proxy_hostid': '0',
#   'host': 'CBA 0467916',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CBA 0467916',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10324', 'name': 'Oi SNMP'}]},
#  {'hostid': '10318',
#   'proxy_hostid': '0',
#   'host': 'RJO 9990908',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RJO 9990908',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10324', 'name': 'Oi SNMP'}]},
#  {'hostid': '10319',
#   'proxy_hostid': '0',
#   'host': 'CBA 0467918',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CBA 0467918',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10324', 'name': 'Oi SNMP'}]},
#  {'hostid': '10320',
#   'proxy_hostid': '0',
#   'host': 'RJO 9990886',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RJO 9990886',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10324', 'name': 'Oi SNMP'}]},
#  {'hostid': '10321',
#   'proxy_hostid': '0',
#   'host': 'RFeye002300',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002300',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10322',
#   'proxy_hostid': '0',
#   'host': 'MNS_IP_05838',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'MNS/IP/05838',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10325',
#   'proxy_hostid': '0',
#   'host': 'AJU_IP_07781',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'AJU/IP/07781',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10326',
#   'proxy_hostid': '0',
#   'host': 'ARC_IP_00955',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'ARC/IP/00955',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10327',
#   'proxy_hostid': '0',
#   'host': 'BAC_IP_00104',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'BAC/IP/00104',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10328',
#   'proxy_hostid': '0',
#   'host': 'BRU_IP_03768',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'BRU/IP/03768',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10329',
#   'proxy_hostid': '0',
#   'host': 'SGM_IP_00230',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'SGM/IP/00230',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10330',
#   'proxy_hostid': '0',
#   'host': 'CAN_IP_01374',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CAN/IP/01374',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10331',
#   'proxy_hostid': '0',
#   'host': 'CPV_IP_00256',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CPV/IP/00256',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10332',
#   'proxy_hostid': '0',
#   'host': 'FLA_IP_09254',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'FLA/IP/09254',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10333',
#   'proxy_hostid': '0',
#   'host': 'FLA_IP_09255',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'FLA/IP/09255',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10334',
#   'proxy_hostid': '0',
#   'host': 'FLA_IP_09261',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'FLA/IP/09261',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10336',
#   'proxy_hostid': '0',
#   'host': 'FOZ_IP_00701',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'FOZ/IP/00701',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10337',
#   'proxy_hostid': '0',
#   'host': 'FOZ_IP_00707',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'FOZ/IP/00707',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10338',
#   'proxy_hostid': '0',
#   'host': 'GIA_IP_00131',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'GIA/IP/00131',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10339',
#   'proxy_hostid': '0',
#   'host': 'GRS_IP_06661',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'GRS/IP/06661',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10340',
#   'proxy_hostid': '0',
#   'host': 'JVE_IP_01801',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'JVE/IP/01801',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10341',
#   'proxy_hostid': '0',
#   'host': 'LDA_IP_01538',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'LDA/IP/01538',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10342',
#   'proxy_hostid': '0',
#   'host': 'LIS_IP_01054',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'LIS/IP/01054',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10343',
#   'proxy_hostid': '0',
#   'host': 'LNA_IP_00264',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'LNA/IP/00264',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10344',
#   'proxy_hostid': '0',
#   'host': 'MBA_IP_00802',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'MBA/IP/00802',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10345',
#   'proxy_hostid': '0',
#   'host': 'MGA_IP_01304',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'MGA/IP/01304',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10347',
#   'proxy_hostid': '0',
#   'host': 'MPA_IP_00904',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'MPA/IP/00904',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10348',
#   'proxy_hostid': '0',
#   'host': 'NVG_IP_00274',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'NVG/IP/00274',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10349',
#   'proxy_hostid': '0',
#   'host': 'PAA_IP_02859',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'PAA/IP/02859',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10350',
#   'proxy_hostid': '0',
#   'host': 'PAE_IP_19225',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'PAE/IP/19225',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10351',
#   'proxy_hostid': '0',
#   'host': 'PAE_IP_19227',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'PAE/IP/19227',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10352',
#   'proxy_hostid': '0',
#   'host': 'PGE_IP_01882',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'PGE/IP/01882',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10353',
#   'proxy_hostid': '0',
#   'host': 'PGU_IP_01124',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'PGU/IP/01124',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10354',
#   'proxy_hostid': '0',
#   'host': 'RGO_IP_00175',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RGO/IP/00175',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10355',
#   'proxy_hostid': '0',
#   'host': 'RPO_IP_07500',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RPO/IP/07500',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10356',
#   'proxy_hostid': '0',
#   'host': 'SCL_IP_01967',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'SCL/IP/01967',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10357',
#   'proxy_hostid': '0',
#   'host': 'SDR_IP_29976',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'SDR/IP/29976',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10358',
#   'proxy_hostid': '0',
#   'host': 'SJP_IP_01317',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'SJP/IP/01317',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10359',
#   'proxy_hostid': '0',
#   'host': 'SOC_IP_05908',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'SOC/IP/05908',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10360',
#   'proxy_hostid': '0',
#   'host': 'SRR_IP_04284',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'SRR/IP/04284',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10361',
#   'proxy_hostid': '0',
#   'host': 'SVE_IP_01664',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'SVE/IP/01664',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10362',
#   'proxy_hostid': '0',
#   'host': 'TSA_IP_06224',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'TSA/IP/06224',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10323', 'name': 'Claro SNMP'}]},
#  {'hostid': '10363',
#   'proxy_hostid': '0',
#   'host': 'RFeye002046',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002046',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10364',
#   'proxy_hostid': '0',
#   'host': 'RFeye002073',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002073',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10365',
#   'proxy_hostid': '0',
#   'host': 'RFEye002076_OVPN',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFEye002076_OVPN',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10598', 'name': 'RFeye OVPN'}]},
#  {'hostid': '10366',
#   'proxy_hostid': '0',
#   'host': 'RFEye002079_OVPN',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFEye002079_OVPN',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10598', 'name': 'RFeye OVPN'}]},
#  {'hostid': '10367',
#   'proxy_hostid': '0',
#   'host': 'RFeye002080',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002080',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10368',
#   'proxy_hostid': '0',
#   'host': 'RFeye002081',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002081',
#   'flags': '0',
#   'templateid': '0',
#   'description': 'IP público 189.10.108.58',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10369',
#   'proxy_hostid': '0',
#   'host': 'RFeye002083',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002083',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10370',
#   'proxy_hostid': '0',
#   'host': 'RFEye002084_OVPN',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFEye002084_OVPN',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10598', 'name': 'RFeye OVPN'}]},
#  {'hostid': '10371',
#   'proxy_hostid': '0',
#   'host': 'RFEye002086_OVPN',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFEye002086_OVPN',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10598', 'name': 'RFeye OVPN'}]},
#  {'hostid': '10372',
#   'proxy_hostid': '0',
#   'host': 'RFeye002087',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002087',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10373',
#   'proxy_hostid': '0',
#   'host': 'RFeye002088',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002088',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': []},
#  {'hostid': '10374',
#   'proxy_hostid': '0',
#   'host': 'RFEye002089_OVPN',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFEye002089_OVPN',
#   'flags': '0',
#   'templateid': '0',
#   'description': 'Dificuldade de acesso e configuração da rfeye',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10598', 'name': 'RFeye OVPN'}]},
#  {'hostid': '10375',
#   'proxy_hostid': '0',
#   'host': 'RFeye002090',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002090',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10376',
#   'proxy_hostid': '0',
#   'host': 'RFeye002092',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002092',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10377',
#   'proxy_hostid': '0',
#   'host': 'RFeye002093',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002093',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': []},
#  {'hostid': '10378',
#   'proxy_hostid': '0',
#   'host': 'RFeye002094',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002094',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10379',
#   'proxy_hostid': '0',
#   'host': 'RFeye002095',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002095',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': []},
#  {'hostid': '10380',
#   'proxy_hostid': '0',
#   'host': 'RFeye002096',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002096',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': []},
#  {'hostid': '10381',
#   'proxy_hostid': '0',
#   'host': 'RFEye002097_OVPN',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFEye002097_OVPN',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10598', 'name': 'RFeye OVPN'}]},
#  {'hostid': '10382',
#   'proxy_hostid': '0',
#   'host': 'RFeye002098',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002098',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10383',
#   'proxy_hostid': '0',
#   'host': 'RFeye002100',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002100',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': []},
#  {'hostid': '10384',
#   'proxy_hostid': '0',
#   'host': 'RFEye002101_OVPN',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFEye002101_OVPN',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10598', 'name': 'RFeye OVPN'}]},
#  {'hostid': '10385',
#   'proxy_hostid': '0',
#   'host': 'RFeye002102',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
# ...
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM220041',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '1',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]},
#  {'hostid': '10774',
#   'proxy_hostid': '0',
#   'host': 'CWSM211003',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM211003',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '1',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]},
#  {'hostid': '10775',
#   'proxy_hostid': '0',
#   'host': 'CWSM220046',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM220046',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '1',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]},
#  {'hostid': '10776',
#   'proxy_hostid': '0',
#   'host': 'CWSM220045',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM220045',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '1',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]},
#  {'hostid': '10777',
#   'proxy_hostid': '0',
#   'host': 'CWSM211016',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM211016',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '1',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]},
#  {'hostid': '10778',
#   'proxy_hostid': '0',
#   'host': 'CWSM220043',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM220043',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '1',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]},
#  {'hostid': '10779',
#   'proxy_hostid': '0',
#   'host': 'RFeye002073 teste',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002073 teste',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10780',
#   'proxy_hostid': '0',
#   'host': 'RFeye002076 teste',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002076 teste',
#   'flags': '0',
#   'templateid': '0',
#   'description': 'Cadastro com locais e coordenadas incorretas apenas para testes no grafana',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10781',
#   'proxy_hostid': '0',
#   'host': 'RFeye002086 teste',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002086 teste',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10782',
#   'proxy_hostid': '0',
#   'host': 'RFeye002081 teste',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002081 teste',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10783',
#   'proxy_hostid': '0',
#   'host': 'RFeye002088 teste',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002088 teste',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10784',
#   'proxy_hostid': '0',
#   'host': 'RFeye002096 teste',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002096 teste',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10785',
#   'proxy_hostid': '0',
#   'host': 'RFeye002101 teste',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002101 teste',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10786',
#   'proxy_hostid': '0',
#   'host': 'RFeye002235 teste',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002235 teste',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10787',
#   'proxy_hostid': '0',
#   'host': 'UMSDF1 teste',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'UMSDF1 teste',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10788',
#   'proxy_hostid': '0',
#   'host': 'CWSM211009 teste',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM211009 teste',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]},
#  {'hostid': '10789',
#   'proxy_hostid': '0',
#   'host': 'CWSM211001 teste',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM211001 teste',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]},
#  {'hostid': '10790',
#   'proxy_hostid': '0',
#   'host': 'CWSM211010 teste',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM211010 teste',
#   'flags': '0',
#   'templateid': '0',
#   'description': 'Cadastro com locais e coordenadas incorretas apenas para testes no grafana',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]},
#  {'hostid': '10793',
#   'proxy_hostid': '0',
#   'host': 'CWSM211011',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM211011',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '1',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]},
#  {'hostid': '10794',
#   'proxy_hostid': '0',
#   'host': 'CWSM211012',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM211012',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '1',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]},
#  {'hostid': '10795',
#   'proxy_hostid': '0',
#   'host': 'CWSM211013',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM211013',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '1',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]},
#  {'hostid': '10796',
#   'proxy_hostid': '0',
#   'host': 'BHE 6767637',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'BHE 6767637 - new',
#   'flags': '0',
#   'templateid': '0',
#   'description': '187.76.239.217',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10324', 'name': 'Oi SNMP'}]},
#  {'hostid': '10798',
#   'proxy_hostid': '0',
#   'host': 'RFeye002012',
#   'status': '1',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'RFeye002012',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '0',
#   'parentTemplates': [{'templateid': '10308', 'name': 'RFEye Nodes'}]},
#  {'hostid': '10800',
#   'proxy_hostid': '0',
#   'host': 'CWSM211015',
#   'status': '0',
#   'lastaccess': '0',
#   'ipmi_authtype': '-1',
#   'ipmi_privilege': '2',
#   'ipmi_username': '',
#   'ipmi_password': '',
#   'maintenanceid': '0',
#   'maintenance_status': '0',
#   'maintenance_type': '0',
#   'maintenance_from': '0',
#   'name': 'CWSM211015',
#   'flags': '0',
#   'templateid': '0',
#   'description': '',
#   'tls_connect': '1',
#   'tls_accept': '1',
#   'tls_issuer': '',
#   'tls_subject': '',
#   'proxy_address': '',
#   'auto_compress': '1',
#   'custom_interfaces': '0',
#   'uuid': '',
#   'inventory_mode': '1',
#   'parentTemplates': [{'templateid': '10764', 'name': 'CW RMU'}]}]

# %% [markdown]
# Let us know that:
# "
#     {'templateid': '10308', 'name': 'RFEye Nodes'}
#     {'templateid': '10764', 'name': 'CW RMU'}
# "
# ### Select main hosts

# %%
df_main_host = df_clean_data[df_clean_data['N_host_Oficial']==True]

# %% [markdown]
# # Update host IP/DNS

# %%
def update_IP(host): 
    try:
        zbx_dict = zapi.hostinterface.update(interfaceid=host['interfaceid'], ip=host['IP'])
    except Exception as e:
        print(f"----> ERROR: {host['interfaceid']} - {host['IP']}")
        print(e)

df = df_clean_data[['interfaceid','IP']].copy()
df = df.dropna()
none = df.apply(update_IP, axis=1)
# Out:
# ----> ERROR: 222 - 200146174227
# ('Error -32602: Invalid params., Invalid IP address "200146174227".', -32602)

# %%
def update_DNS(host): 
    try:
        zbx_dict = zapi.hostinterface.update(interfaceid=host['interfaceid'], dns=host['DNS'])
    except Exception as e:
        print(f"----> ERROR: {host['interfaceid']} - {host['DNS']}")
        print(e)

df = df_clean_data[['interfaceid','DNS']].copy()
df = df.dropna()
none = df.apply(update_DNS, axis=1)

# %% [markdown]
# # Update host names

# %%
def update_name(host): 
    try:
        zbx_dict = zapi.host.update(hostid=host['hostid'], host=host['N_host_name'])
    except Exception as e:
        print(f"----> ERROR: {host['hostid']} - {host['N_host_name']}")
        print(e)
        
none = df_clean_data.apply(update_name, axis=1)
# Out:
# ----> ERROR: 10605 - RFEye002233_ovpn
# ('Error -32602: Invalid params., Host with the same name "RFEye002233_ovpn" already exists.', -32602)
# ----> ERROR: 10651 - RFEye002263_ovpn
# ('Error -32602: Invalid params., Host with the same name "RFEye002263_ovpn" already exists.', -32602)
# ----> ERROR: 10652 - RFEye002264_ovpn
# ('Error -32602: Invalid params., Host with the same name "RFEye002264_ovpn" already exists.', -32602)

# %% [markdown]
# ----> ERROR: 10605 - RFEye002233_ovpn
# ('Error -32602: Invalid params., Host with the same name "RFEye002233_ovpn" already exists.', -32602)
# ----> ERROR: 10651 - RFEye002263_ovpn
# ('Error -32602: Invalid params., Host with the same name "RFEye002263_ovpn" already exists.', -32602)
# ----> ERROR: 10652 - RFEye002264_ovpn
# ('Error -32602: Invalid params., Host with the same name "RFEye002264_ovpn" already exists.', -32602)

# %% [markdown]
# # Scratch block
#
# Output fron rfeye
#
# {"SystemTime": "2023-04-11 06:46:10","GPS": "095353 110423 1 1 10 -2584172 -44237551 6 0 50200 ","IP": "201.73.195.82","FreeMemory": "415308 kB"}
#
# Test VISA connection with NCAT
#
# <code>Bash
# echo -e "*IDN?\n:STATUS:TEMPERATURE?\n:GNSS:POSITION?\n*OPC\n" | nc -C CWSM211008.anatel.gov.br 37001 > teste.txt
# </code>
#
# Zabbix automation cron jobs
#
# <code>Bash
# lx.svc.fi.sensores.pd@rhzbefipdin01:~$ crontab -l
#
# 0 3 * * * sh /home/lx.svc.fi.sensores.pd/scripts_automacao/Automation_criaBD.sh
#
# 0 5 * * * sh /home/lx.svc.fi.sensores.pd/scripts_automacao/Automation_verificaBD.sh
#
# 0 6 * * * sh /home/lx.svc.fi.sensores.pd/scripts_automacao/Automation_Aplicacoes.sh
# </code>

# %% [markdown]
# Fix hosts

# %%
"""
Zabbix stores the DNS name and the IP for each host that it monitors, and
uses one or the other to connect to the host.  It is good practice to make
sure the IP and DNS name are both correct.  This script checks the DNS and
IP for all hosts in Zabbix, compares the IP against an actual DNS lookup,
and fixes it if required.
"""

import socket

from pyzabbix import ZabbixAPI, ZabbixAPIException

# The hostname at which the Zabbix web interface is available
ZABBIX_SERVER = "https://zabbix.example.com"

zapi = ZabbixAPI(ZABBIX_SERVER)

# Disable SSL certificate verification
zapi.session.verify = False

# Login to the Zabbix API
zapi.login("Admin", "zabbix")

# Loop through all hosts interfaces, getting only "main" interfaces of type "agent"
for h in zapi.hostinterface.get(
    output=["dns", "ip", "useip"], selectHosts=["host"], filter={"main": 1, "type": 1}
):
    # Make sure the hosts are named according to their FQDN
    if h["dns"] != h["hosts"][0]["host"]:
        print('Warning: {} has dns "{}"'.format(h["hosts"][0]["host"], h["dns"]))

    # Make sure they are using hostnames to connect rather than IPs (could be also filtered in the get request)
    if h["useip"] == "1":
        print("%s is using IP instead of hostname. Skipping." % h["hosts"][0]["host"])
        continue

    # Do a DNS lookup for the host's DNS name
    try:
        lookup = socket.gethostbyaddr(h["dns"])
    except socket.gaierror as e:
        print(h["dns"], e)
        continue
    actual_ip = lookup[2][0]

    # Check whether the looked-up IP matches the one stored in the host's IP
    # field
    if actual_ip != h["ip"]:
        print(
            "%s has the wrong IP: %s. Changing it to: %s"
            % (h["hosts"][0]["host"], h["ip"], actual_ip)
        )

        # Set the host's IP field to match what the DNS lookup said it should
        # be
        try:
            zapi.hostinterface.update(interfaceid=h["interfaceid"], ip=actual_ip)
        except ZabbixAPIException as e:
            print(e)
